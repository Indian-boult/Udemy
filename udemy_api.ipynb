# %%
from udemy import *

# %%
clientID = "ubzvaIGjQZo1udpMzdkQqQ2alXfdUruaZZhNUhLR"
clientSecret = 'eaOxJyEP5IkZCOsPqt8vDAuAfuKpH5lhZd65e2ekZDxBF5mhil2lkoNItKq9rTgQslF7lKj0rD8uliQHFrznpKK1E9ZhZ5d7G2s224v1h6S25TEsx1tREL8pvZpj5gS2'

# %%
Client = PyUdemy(clientID=clientID, clientSecret=clientSecret)

# %%
courses = Client.get_courseslist()

# %%
courses
# Out:
# '{"count":10000,"next":"https://www.udemy.com/api-2.0/courses/?page=2&page_size=12","previous":null,"results":[{"_class":"course","id":362328,"title":"AWS Certified Solutions Architect - Associate 2020","url":"/course/aws-certified-solutions-architect-associate/","is_paid":true,"price":"$179.99","price_detail":{"currency":"USD","amount":179.99,"price_string":"$179.99","currency_symbol":"$"},"visible_instructors":[{"image_100x100":"https://i.udemycdn.com/user/100x100/646294_3e1d_3.jpg","image_50x50":"https://i.udemycdn.com/user/50x50/646294_3e1d_3.jpg","name":"Ryan","initials":"RK","url":"/user/ryankroonenburg/","title":"Ryan Kroonenburg","display_name":"Ryan Kroonenburg","_class":"user","job_title":"Solutions Architect"},{"image_100x100":"https://i.udemycdn.com/user/100x100/44848936_b7c8_2.jpg","image_50x50":"https://i.udemycdn.com/user/50x50/44848936_b7c8_2.jpg","name":"Faye","initials":"FE","url":"/user/faye-ellis-2/","title":"Faye Ellis","display_name":"Faye Ellis","_class":"user"
# ...
